# %%
#LOADING MAIN LIBRARIES
import xarray as xr
import numpy as np
import matplotlib
# matplotlib.use("Agg") #figures are not sent to the Jupyter frontend #*#* (turn off if wanting to see plots in Notebook)
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

from tqdm import tqdm

import os

# %%
#SETTING UP MAIN DIRECTORIES
mainDirectory = "/glade/u/home/aroseman/Projects/Regional-MPAS-Project/Code/CodeFiles/"

# %%
#DIRECTORY FUNCTIONS
def ListFiles(directory, n=10):
    files = os.listdir(directory)
    # print("Listing first", n, "files:\n", files[:n], "\n")
    return files

# %%
#LOADING CLASSES
# --- Add your Functions folder to sys.path ---
import sys
path = mainDirectory + '/Functions_2.0/Classes'
sys.path.append(path)

# --- Import all your function modules ---
import importlib
modules = [
    "Classes_MapPlotting"
]

for mod in modules:
    globals()[mod] = importlib.import_module(mod)        # import module itself
    globals().update(vars(globals()[mod]))              # import all functions into global namespace

# %%
################################################################################

# %%
#DATA DESCRIPTIONS

### Data Type
# C-Band Scanning ARM Precipitation Radar (CSAPR2)

### DOI (Permanent Link)
# https://armgov.svcs.arm.gov/capabilities/instruments/csapr

### Summary
# The C-Band Scanning ARM Precipitation Radar is a dual-polarization 
# Doppler weather radar that operates in a simultaneous transmit
# and receive (STAR) mode, splitting the transmit signal so that power
# is transmitted on both horizontal and vertical polarizations at the same time. 
# The CSAPR can also transmit on a single polarization (horizontal or vertical) 
# and measure linear depolarization ratio (LDR).

### Temporal Coverage

### Spatial Coverage

# %%
import math

def bounding_box(lat, lon, dist_km):
    """
    Compute bounding box corners around (lat, lon), extending dist_km in each direction,
    using Earth radius (no 111-km approximation).

    Parameters
    ----------
    lat : float
        Latitude in degrees (positive north).
    lon : float
        Longitude in degrees (positive east; negative for west).
    dist_km : float
        Distance in kilometers to extend in each direction.

    Returns
    -------
    dict
        Dictionary with keys 'SW', 'SE', 'NE', 'NW' and (lat, lon) tuples.
    """
    R = 6371.0  # Earth radius in km
    
    # Convert to radians
    lat_rad = math.radians(lat)
    
    # Degree offsets
    dlat = (dist_km / R) * (180 / math.pi)
    dlon = (dist_km / (R * math.cos(lat_rad))) * (180 / math.pi)
    
    corners = {
        "SW": (lat - dlat, lon - dlon),
        "SE": (lat - dlat, lon + dlon),
        "NE": (lat + dlat, lon + dlon),
        "NW": (lat + dlat, lon - dlon),
    }
    return corners

# Example
lat0, lon0 = 29.532, -95.284
corners = bounding_box(lat0, lon0, 250)
for name, coords in corners.items():
    print(f"{name}: {coords}")
# Out:
# SW: (27.283695985203174, -97.86801827645755)
# SE: (27.283695985203174, -92.69998172354246)
# NE: (31.780304014796826, -92.69998172354246)
# NW: (31.780304014796826, -97.86801827645755)

# %%
mapPlotting = MapPlotting(
    sw_corner=(27.28, -97.87),  # (lat_min, lon_min)
    ne_corner=(31.78, -92.70),  # (lat_max, lon_max)
    delta=3,
    fontsize=7
)
mapPlotting.PlotBoundingBox()

# %%
################################################################################

# %%
#SET UP DIRECTORIES
Campaign="TRACER"
DataType="CBand_Radar"
RadarType="PPI"

#Code Directory
Code_Directory="/glade/u/home/aroseman/Projects/Regional-MPAS-Project/Code/CodeFiles/DataAnalysis/Observation_Data"
Code_Directory=os.path.join(Code_Directory,Campaign)
print("Code Directory Set as:", Code_Directory, '\n')

def GetDataDirectory(Campaign=Campaign,
                     DataType=DataType,
                     RadarType=RadarType,
                     BaseDir="/glade/work/aroseman/Projects/Regional-MPAS-Project/Code/DATA/Observation_Data",
                    ):
                     
                     
    #old base directory: BaseDir="/glade/derecho/scratch/aroseman/Projects/Regional-MPAS-Project/Code/DATA/Observation_Data"
    Data_Directory = os.path.join(BaseDir, Campaign, DataType, RadarType.lower()) 
    #SUR is the same as PPI (Plan Position Indicator) radar, RHI is Range-Height-Indicator
    print("Data Directory Set as:", Data_Directory, '\n')
    FileList = np.sort(ListFiles(Data_Directory))
    return Data_Directory, FileList
# Data_Directory, FileList=GetDataDirectory(RadarType="PPI") #hsrhi  ppi  rhi  vpt

#Output Directory
Output_Directory="/glade/u/home/aroseman/Projects/Regional-MPAS-Project/Code/OUTPUT/DataAnalysis/Observation_Data"
Output_Directory=os.path.join(Output_Directory,Campaign,DataType)
# Out:
# Code Directory Set as: /glade/u/home/aroseman/Projects/Regional-MPAS-Project/Code/CodeFiles/DataAnalysis/Observation_Data/TRACER

# %%
#READING DATA
###################################
#how to unzip in terminal
# mkdir -p unzip
# for f in *.tar; do
#     tar -xvf "$f" -C unzip
# done

# %%
def GetData(Data_Directory, FileList, index):
    DataFile = os.path.join(Data_Directory,FileList[index])
    print(f"Downloading File:\n {DataFile}","\n")
    DataNC = xr.open_dataset(DataFile,decode_timedelta=True)
    return DataNC, DataFile

# %%
# Citing Py-ART (Toolkit for interpolating and plotting radar data (PPI and RHI)
# If you use Py-ART in your work please cite it in your paper. While the developers appreciate mentions in the text and acknowledgements citing the paper helps more.

# For Py-ART cite our paper in the Journal of Open Research Software

# Helmus, J.J. & Collis, S.M., (2016). The Python ARM Radar Toolkit (Py-ART), a Library for Working with Weather Radar Data in the Python Programming Language. Journal of Open Research Software. 4(1), p.e25. DOI: http://doi.org/10.5334/jors.119

# For a general citation on Open Radar Software please cite Maik Heistermann in BAMS

# M. Heistermann, S. Collis, M. J. Dixon, S. Giangrande, J. J. Helmus, B. Kelley, J. Koistinen, D. B. Michelson, M. Peura, T. Pfaff, and D. B. Wolff, 2015: The Emergence of Open-Source Software for the Weather Radar Community. Bull. Amer. Meteor. Soc. 96, 117–128, doi: 10.1175/BAMS-D-13-00240.1.

# %%
import os
import pyart
import matplotlib.pyplot as plt
import numpy as np
from pyart.map import grid_from_radars


def combine_radars_from_files(file_list):
    """Reads a list of radar files and combines them into a single Radar object."""
    if not file_list:
        return None
    combined_radar = pyart.io.read(file_list[0])
    for filename in file_list[1:]:
        print(f"Joining {os.path.basename(filename)}...")
        next_radar = pyart.io.read(filename)
        combined_radar = pyart.util.join_radar(combined_radar, next_radar)
    return combined_radar


class RadarScan:
    def __init__(self, RadarType="PPI", date="20220630",
                 start_time="00:00:00", interval_sec=15):
        """
        Initialize a RadarScan object using Py-ART.

        Parameters
        ----------
        RadarType : str
            Radar type (PPI, RHI, etc.).
        date : str
            Date string in YYYYMMDD format.
        start_time : str
            Starting timestamp (HH:MM:SS).
        interval_sec : int
            Interval length (in seconds).
        """
        # Load file list for this radar type/date
        self.Data_Directory, self.FileList = GetDataDirectory(RadarType=RadarType)
        self.FileList = [f for f in self.FileList if date in f]
        if not self.FileList:
            raise FileNotFoundError(f"No radar files found for date {date}")

        # Filter files into the requested time window
        self.FileList = self._filter_files_by_time(self.FileList, start_time, interval_sec)
        if not self.FileList:
            raise FileNotFoundError(f"No files found between {start_time} and +{interval_sec}s on {date}")

        # Full paths
        self.DataFiles = [os.path.join(self.Data_Directory, f) for f in self.FileList]
        self.DataName = f"{RadarType}_{date}_{start_time}_{interval_sec}s ({len(self.DataFiles)} files)"

        # Combine radar files
        self.radar = combine_radars_from_files(self.DataFiles)

        # Extract metadata & variables
        self._extract_metadata()
        self._extract_variables()
        self._get_PyArt_colormaps()

    # -------------------------------
    # Helper functions
    # -------------------------------
    def _time_to_seconds(self, timestr):
        """Convert HH:MM:SS string to seconds from midnight."""
        h, m, s = map(int, timestr.split(":"))
        return h * 3600 + m * 60 + s

    def _file_seconds(self, fname):
        """Extract seconds from filename timestamp (...YYYYMMDD.HHMMSS.nc)."""
        timestr = fname.split(".")[-2]  # e.g., "000822"
        hh, mm, ss = int(timestr[0:2]), int(timestr[2:4]), int(timestr[4:6])
        return hh * 3600 + mm * 60 + ss

    def _filter_files_by_time(self, file_list, start_time, interval_sec):
        """Filter radar files that fall into the time window [start, start+interval]."""
        start_sec = self._time_to_seconds(start_time)
        end_sec = start_sec + interval_sec
        return [f for f in file_list
                if start_sec <= self._file_seconds(f) <= end_sec]

    # -------------------------------
    # Metadata and fields
    # -------------------------------
    def _extract_metadata(self):
        self.radar_latitude  = float(self.radar.latitude['data'][0])
        self.radar_longitude = float(self.radar.longitude['data'][0])
        self.radar_altitude  = float(self.radar.altitude['data'][0])
        self.nt = self.radar.nrays
        self.nr = self.radar.ngates
        self.nsweeps = self.radar.nsweeps
        self.times      = self.radar.time['data']
        self.ranges     = self.radar.range['data']
        self.azimuths   = self.radar.azimuth['data']
        self.elevations = self.radar.elevation['data']
        self.TimeRange = (self.times[0], self.times[-1])

    def _extract_variables(self):
        if "reflectivity" in self.radar.fields:
            self.reflectivity = self.radar.fields["reflectivity"]["data"]
        else:
            raise KeyError("Reflectivity field not found in radar file.")

    def _get_PyArt_colormaps(self):
        self.cmap_reflectivity = pyart.config.get_field_colormap("reflectivity")

    # -------------------------------
    # Public methods
    # -------------------------------
    def summary(self):
        print(f"Radar dataset: {self.DataName}")
        print(f"Radar location: ({self.radar_latitude:.4f}, "
              f"{self.radar_longitude:.4f}, {self.radar_altitude:.1f} m)")
        print(f"Number of sweeps: {self.nsweeps}")
        print(f"Reflectivity shape: {self.reflectivity.shape}")
        print(f"Time range: {self.TimeRange}")

    # def PlotReflectivityAllSweeps(self, vmin=-10, vmax=60):
    #     """Overlay all sweeps (native polar coordinates) in a single PPI plot."""
    #     display = pyart.graph.RadarDisplay(self.radar)
    #     fig, ax = plt.subplots(figsize=(7, 6))

    #     for sweep in range(self.nsweeps):
    #         display.plot_ppi(
    #             'reflectivity',
    #             sweep=sweep,
    #             vmin=vmin, vmax=vmax,
    #             cmap=self.cmap_reflectivity,
    #             ax=ax,
    #             colorbar_flag=(sweep == self.nsweeps - 1),
    #             colorbar_label='Reflectivity (dBZ)' if sweep == self.nsweeps - 1 else None
    #         )

    #     ax.set_title("PPI Reflectivity – All Sweeps")
    #     ax.set_aspect("equal")
    #     plt.show()

    def PlotReflectivityAllSweeps(self, vmin=-10, vmax=60):
        """Plot each sweep in its own subplot."""
        display = pyart.graph.RadarDisplay(self.radar)
    
        n = self.nsweeps
        ncols = 3
        nrows = int(np.ceil(n / ncols))
    
        fig, axes = plt.subplots(nrows, ncols, figsize=(5*ncols, 5*nrows))
    
        axes = axes.flatten()
        for sweep in range(n):
            display.plot_ppi(
                'reflectivity',
                sweep=sweep,
                vmin=vmin, vmax=vmax,
                cmap=self.cmap_reflectivity,
                ax=axes[sweep],
                colorbar_flag=True,
                colorbar_label='Reflectivity (dBZ)'
            )
            elev = self.radar.fixed_angle['data'][sweep]
            axes[sweep].set_title(f"Sweep {sweep} ({elev:.1f}°)")
            axes[sweep].set_aspect("equal")
    
        # Hide any unused axes
        for ax in axes[n:]:
            ax.set_visible(False)
    
        plt.tight_layout()
        plt.show()

# %%
import os
import pyart
import matplotlib.pyplot as plt
import numpy as np
from pyart.map import grid_from_radars


def combine_radars_from_files(file_list):
    """Reads a list of radar files and combines them into a single Radar object."""
    if not file_list:
        return None
    combined_radar = pyart.io.read(file_list[0])
    for filename in file_list[1:]:
        print(f"Joining {os.path.basename(filename)}...")
        next_radar = pyart.io.read(filename)
        combined_radar = pyart.util.join_radar(combined_radar, next_radar)
    return combined_radar


class RadarScan:
    def __init__(self, RadarType="PPI", date="20220630",
                 start_time="00:00:00", interval_sec=15):
        """
        Initialize a RadarScan object using Py-ART.

        Parameters
        ----------
        RadarType : str
            Radar type (PPI, RHI, etc.).
        date : str
            Date string in YYYYMMDD format.
        start_time : str
            Starting timestamp (HH:MM:SS).
        interval_sec : int
            Interval length (in seconds).
        """
        self.RadarType = RadarType.upper()

        # Load file list
        self.Data_Directory, self.FileList = GetDataDirectory(RadarType=self.RadarType)
        self.FileList = [f for f in self.FileList if date in f]
        if not self.FileList:
            raise FileNotFoundError(f"No radar files found for date {date}")

        # Time filter
        self.FileList = self._filter_files_by_time(self.FileList, start_time, interval_sec)
        if not self.FileList:
            raise FileNotFoundError(f"No files found between {start_time} and +{interval_sec}s on {date}")

        # Full paths
        self.DataFiles = [os.path.join(self.Data_Directory, f) for f in self.FileList]
        self.DataName = f"{self.RadarType}_{date}_{start_time}_{interval_sec}s ({len(self.DataFiles)} files)"

        # Combine radar files
        print("Combining Multiple Sweep Files: ", self.DataFiles)
        self.radar = combine_radars_from_files(self.DataFiles)

        # Extract metadata
        self._extract_metadata()
        self._extract_variables()
        self._get_PyArt_colormaps()

    # -------------------------------
    # Helpers
    # -------------------------------
    def _time_to_seconds(self, timestr):
        h, m, s = map(int, timestr.split(":"))
        return h*3600 + m*60 + s

    def _file_seconds(self, fname):
        timestr = fname.split(".")[-2]  # e.g., 000822
        hh, mm, ss = int(timestr[0:2]), int(timestr[2:4]), int(timestr[4:6])
        return hh*3600 + mm*60 + ss

    def _filter_files_by_time(self, file_list, start_time, interval_sec):
        start_sec = self._time_to_seconds(start_time)
        end_sec = start_sec + interval_sec
        return [f for f in file_list
                if start_sec <= self._file_seconds(f) <= end_sec]

    # -------------------------------
    # Metadata and fields
    # -------------------------------
    def _extract_metadata(self):
        self.radar_latitude  = float(self.radar.latitude['data'][0])
        self.radar_longitude = float(self.radar.longitude['data'][0])
        self.radar_altitude  = float(self.radar.altitude['data'][0])
        self.nt = self.radar.nrays
        self.nr = self.radar.ngates
        self.nsweeps = self.radar.nsweeps
        self.times      = self.radar.time['data']
        self.ranges     = self.radar.range['data']
        self.azimuths   = self.radar.azimuth['data']
        self.elevations = self.radar.elevation['data']
        self.TimeRange = (self.times[0], self.times[-1])

    def _extract_variables(self):
        if "reflectivity" in self.radar.fields:
            self.reflectivity = self.radar.fields["reflectivity"]["data"]
        else:
            raise KeyError("Reflectivity field not found in radar file.")

    def _get_PyArt_colormaps(self):
        self.cmap_reflectivity = pyart.config.get_field_colormap("reflectivity")

    # -------------------------------
    # Public methods
    # -------------------------------
    def summary(self):
        print(f"Radar dataset: {self.DataName}")
        print(f"Radar location: ({self.radar_latitude:.4f}, "
              f"{self.radar_longitude:.4f}, {self.radar_altitude:.1f} m)")
        print(f"Number of sweeps: {self.nsweeps}")
        print(f"Reflectivity shape: {self.reflectivity.shape}")
        print(f"Time range: {self.TimeRange}")

    def PlotReflectivityAllSweeps(self, vmin=-10, vmax=60):
        """Plot all sweeps — uses PPI for PPI/PPIV data, RHI for RHI data."""
        display = pyart.graph.RadarDisplay(self.radar)

        n = self.nsweeps
        ncols = 3
        nrows = int(np.ceil(n / ncols))
        fig, axes = plt.subplots(nrows, ncols, figsize=(5*ncols, 5*nrows))
        axes = axes.flatten()

        for sweep in range(n):
            if self.RadarType == "RHI":
                display.plot_rhi(
                    'reflectivity', sweep=sweep,
                    vmin=vmin, vmax=vmax,
                    cmap=self.cmap_reflectivity,
                    ax=axes[sweep], colorbar_flag=True,
                    colorbar_label='Reflectivity (dBZ)'
                )
                az = self.radar.fixed_angle['data'][sweep]
                axes[sweep].set_title(f"RHI {sweep} (Azimuth {az:.1f}°)")
            else:  # default PPI
                display.plot_ppi(
                    'reflectivity', sweep=sweep,
                    vmin=vmin, vmax=vmax,
                    cmap=self.cmap_reflectivity,
                    ax=axes[sweep], colorbar_flag=True,
                    colorbar_label='Reflectivity (dBZ)'
                )
                elev = self.radar.fixed_angle['data'][sweep]
                axes[sweep].set_title(f"PPI {sweep} (Elev {elev:.1f}°)")

            axes[sweep].set_aspect("equal")

        for ax in axes[n:]:
            ax.set_visible(False)

        plt.tight_layout()
        plt.show()

    def PlotVPT(self, vmin=-10, vmax=60):
        """Plot vertical pointing time-height reflectivity (for VPT)."""
        if self.RadarType != "VPT":
            raise ValueError("This method is only for VPT radar type.")
    
        # Reflectivity (time vs. range)
        refl = self.reflectivity
        time = self.radar.time['data']  # seconds since start
        rng  = self.radar.range['data'] / 1000.0  # km
    
        fig, ax = plt.subplots(figsize=(10, 6))
        pcm = ax.pcolormesh(time, rng, refl.T,
                            cmap=self.cmap_reflectivity,
                            vmin=vmin, vmax=vmax)
        plt.colorbar(pcm, ax=ax, label="Reflectivity (dBZ)")
    
        ax.set_xlabel("Time (s since start)")
        ax.set_ylabel("Height (km)")
        ax.set_title("VPT Reflectivity (Time–Height)")
        plt.show()

# %%
# Load files from 00:08:00 to 00:08:15 UTC
scan = RadarScan(RadarType="PPI", date="20220630",
                 start_time="00:08:22", interval_sec=1*60)

scan.summary()
scan.PlotReflectivityAllSweeps()
# Out:
# Data Directory Set as: /glade/work/aroseman/Projects/Regional-MPAS-Project/Code/DATA/Observation_Data/TRACER/CBand_Radar/ppi
#
# Combining Multiple Sweep Files:  ['/glade/work/aroseman/Projects/Regional-MPAS-Project/Code/DATA/Observation_Data/TRACER/CBand_Radar/ppi/houcsapr2cfrqcS2.b1.20220630.000822.nc']
# Radar dataset: PPI_20220630_00:08:22_60s (1 files)
# Radar location: (29.5320, -95.2840, 12.0 m)
# Number of sweeps: 3
# Reflectivity shape: (123, 1100)
# Time range: (502.0, 523.129999)

# %%
# Load files from 00:08:00 to 00:08:15 UTC
scan = RadarScan(RadarType="RHI", date="20220630",
                 start_time="00:08:22", interval_sec=1*60)

scan.summary()
scan.PlotReflectivityAllSweeps()
# Out:
# Data Directory Set as: /glade/work/aroseman/Projects/Regional-MPAS-Project/Code/DATA/Observation_Data/TRACER/CBand_Radar/rhi
#
# Combining Multiple Sweep Files:  ['/glade/work/aroseman/Projects/Regional-MPAS-Project/Code/DATA/Observation_Data/TRACER/CBand_Radar/rhi/houcsapr2cfrqcS2.b1.20220630.000852.nc', '/glade/work/aroseman/Projects/Regional-MPAS-Project/Code/DATA/Observation_Data/TRACER/CBand_Radar/rhi/houcsapr2cfrqcS2.b1.20220630.000906.nc', '/glade/work/aroseman/Projects/Regional-MPAS-Project/Code/DATA/Observation_Data/TRACER/CBand_Radar/rhi/houcsapr2cfrqcS2.b1.20220630.000921.nc']
# Joining houcsapr2cfrqcS2.b1.20220630.000906.nc...
# Joining houcsapr2cfrqcS2.b1.20220630.000921.nc...
# Radar dataset: RHI_20220630_00:08:22_60s (3 files)
# Radar location: (29.5320, -95.2840, 12.0 m)
# Number of sweeps: 3
# Reflectivity shape: (72, 1100)
# Time range: (1656547732.0, 1656547762.901)

# %%
# Load files from 00:08:00 to 00:08:15 UTC
scan = RadarScan(RadarType="HSRHI", date="20220630",
                 start_time="05:40:16", interval_sec=1*60)

scan.summary()
scan.PlotReflectivityAllSweeps()
# Out:
# Data Directory Set as: /glade/work/aroseman/Projects/Regional-MPAS-Project/Code/DATA/Observation_Data/TRACER/CBand_Radar/hsrhi
#
# Combining Multiple Sweep Files:  ['/glade/work/aroseman/Projects/Regional-MPAS-Project/Code/DATA/Observation_Data/TRACER/CBand_Radar/hsrhi/houcsapr2cfrqcS2.b1.20220630.054016.nc']
# Radar dataset: HSRHI_20220630_05:40:16_60s (1 files)
# Radar location: (29.5320, -95.2840, 12.0 m)
# Number of sweeps: 6
# Reflectivity shape: (2172, 1100)
# Time range: (20416.0, 20676.381999)

# %%
# Load files from 00:08:00 to 00:08:15 UTC
# Data_Directory, FileList=GetDataDirectory(RadarType="VPT") #hsrhi  ppi  rhi  vpt
# FileList
scan = RadarScan(RadarType="VPT", date="20220630",
                 start_time="21:47:42", interval_sec=1*60)

scan.summary()
scan.PlotVPT()
# Out:
# Data Directory Set as: /glade/work/aroseman/Projects/Regional-MPAS-Project/Code/DATA/Observation_Data/TRACER/CBand_Radar/vpt
#
# Combining Multiple Sweep Files:  ['/glade/work/aroseman/Projects/Regional-MPAS-Project/Code/DATA/Observation_Data/TRACER/CBand_Radar/vpt/houcsapr2cfrqcS2.b1.20220630.214742.nc']
# Radar dataset: VPT_20220630_21:47:42_60s (1 files)
# Radar location: (29.5320, -95.2840, 12.0 m)
# Number of sweeps: 1
# Reflectivity shape: (360, 200)
# Time range: (78462.0, 78497.871999)

# %%
# Out:
# Data Directory Set as: /glade/work/aroseman/Projects/Regional-MPAS-Project/Code/DATA/Observation_Data/TRACER/CBand_Radar/vpt
# array(['houcsapr2cfrqcS2.b1.20220630.054750.nc',
#        'houcsapr2cfrqcS2.b1.20220630.055755.nc',
#        'houcsapr2cfrqcS2.b1.20220630.060753.nc',
#        'houcsapr2cfrqcS2.b1.20220630.061753.nc',
#        'houcsapr2cfrqcS2.b1.20220630.062756.nc',
#        'houcsapr2cfrqcS2.b1.20220630.063749.nc',
#        'houcsapr2cfrqcS2.b1.20220630.064758.nc',
#        'houcsapr2cfrqcS2.b1.20220630.065748.nc',
#        'houcsapr2cfrqcS2.b1.20220630.070800.nc',
#        'houcsapr2cfrqcS2.b1.20220630.071746.nc',
#        'houcsapr2cfrqcS2.b1.20220630.072801.nc',
#        'houcsapr2cfrqcS2.b1.20220630.073747.nc',
#        'houcsapr2cfrqcS2.b1.20220630.074801.nc',
#        'houcsapr2cfrqcS2.b1.20220630.075746.nc',
#        'houcsapr2cfrqcS2.b1.20220630.080800.nc',
#        'houcsapr2cfrqcS2.b1.20220630.081747.nc',
#        'houcsapr2cfrqcS2.b1.20220630.082801.nc',
#        'houcsapr2cfrqcS2.b1.20220630.083746.nc',
#        'houcsapr2cfrqcS2.b1.20220630.084801.nc',
#        'houcsapr2cfrqcS2.b1.20220630.085746.nc',
#        'houcsapr2cfrqcS2.b1.20220630.090801.nc',
#        'houcsapr2cfrqcS2.b1.20220630.091748.nc',
#        'houcsapr2cfrqcS2.b1.20220630.092758.nc',
#        'houcsapr2cfrqcS2.b1.20220630.093749.nc',
#        'houcsapr2cfrqcS2.b1.20220630.094758.nc',
#        'houcsapr2cfrqcS2.b1.20220630.095749.nc',
#        'houcsapr2cfrqcS2.b1.20220630.100759.nc',
#        'houcsapr2cfrqcS2.b1.20220630.101747.nc',
#        'houcsapr2cfrqcS2.b1.20220630.102758.nc',
#        'houcsapr2cfrqcS2.b1.20220630.103750.nc',
#        'houcsapr2cfrqcS2.b1.20220630.104757.nc',
#        'houcsapr2cfrqcS2.b1.20220630.105750.nc',
#        'houcsapr2cfrqcS2.b1.20220630.110758.nc',
#        'houcsapr2cfrqcS2.b1.20220630.111748.nc',
#        'houcsapr2cfrqcS2.b1.20220630.112759.nc',
#        'houcsapr2cfrqcS2.b1.20220630.113749.nc',
#        'houcsapr2cfrqcS2.b1.20220630.114759.nc',
#        'houcsapr2cfrqcS2.b1.20220630.115747.nc',
#        'houcsapr2cfrqcS2.b1.20220630.120759.nc',
#        'houcsapr2cfrqcS2.b1.20220630.121749.nc',
#        'houcsapr2cfrqcS2.b1.20220630.122758.nc',
#        'houcsapr2cfrqcS2.b1.20220630.123749.nc',
#        'houcsapr2cfrqcS2.b1.20220630.214742.nc',
#        'houcsapr2cfrqcS2.b1.20220630.215759.nc',
#        'houcsapr2cfrqcS2.b1.20220630.220749.nc',
#        'houcsapr2cfrqcS2.b1.20220630.221759.nc',
#        'houcsapr2cfrqcS2.b1.20220630.222750.nc',
#        'houcsapr2cfrqcS2.b1.20220630.223800.nc',
#        'houcsapr2cfrqcS2.b1.20220630.225758.nc',
#        'houcsapr2cfrqcS2.b1.20220630.230729.nc',
#        'houcsapr2cfrqcS2.b1.20220630.231745.nc',
#        'houcsapr2cfrqcS2.b1.20220630.232801.nc',
#        'houcsapr2cfrqcS2.b1.20220630.233746.nc',
#        'houcsapr2cfrqcS2.b1.20220630.234801.nc',
#        'houcsapr2cfrqcS2.b1.20220630.235746.nc',
#        'houcsapr2cfrqcS2.b1.20220701.000800.nc',
#        'houcsapr2cfrqcS2.b1.20220701.001746.nc',
#        'houcsapr2cfrqcS2.b1.20220701.002801.nc',
#        'houcsapr2cfrqcS2.b1.20220701.003746.nc',
#        'houcsapr2cfrqcS2.b1.20220701.004759.nc',
#        'houcsapr2cfrqcS2.b1.20220701.005747.nc',
#        'houcsapr2cfrqcS2.b1.20220701.011747.nc',
#        'houcsapr2cfrqcS2.b1.20220701.012800.nc',
#        'houcsapr2cfrqcS2.b1.20220701.013746.nc',
#        'houcsapr2cfrqcS2.b1.20220701.014800.nc',
#        'houcsapr2cfrqcS2.b1.20220701.015746.nc',
#        'houcsapr2cfrqcS2.b1.20220701.020801.nc',
#        'houcsapr2cfrqcS2.b1.20220701.021746.nc',
#        'houcsapr2cfrqcS2.b1.20220701.022801.nc',
#        'houcsapr2cfrqcS2.b1.20220701.023744.nc',
#        'houcsapr2cfrqcS2.b1.20220701.024802.nc',
#        'houcsapr2cfrqcS2.b1.20220701.025742.nc',
#        'houcsapr2cfrqcS2.b1.20220701.030758.nc',
#        'houcsapr2cfrqcS2.b1.20220701.031746.nc',
#        'houcsapr2cfrqcS2.b1.20220701.032801.nc',
#        'houcsapr2cfrqcS2.b1.20220701.033743.nc',
#        'houcsapr2cfrqcS2.b1.20220701.034758.nc',
#        'houcsapr2cfrqcS2.b1.20220701.035748.nc',
#        'houcsapr2cfrqcS2.b1.20220701.040759.nc',
#        'houcsapr2cfrqcS2.b1.20220701.041745.nc',
#        'houcsapr2cfrqcS2.b1.20220701.042800.nc',
#        'houcsapr2cfrqcS2.b1.20220701.043745.nc',
#        'houcsapr2cfrqcS2.b1.20220701.044801.nc',
#        'houcsapr2cfrqcS2.b1.20220701.045744.nc',
#        'houcsapr2cfrqcS2.b1.20220701.050802.nc',
#        'houcsapr2cfrqcS2.b1.20220701.051745.nc',
#        'houcsapr2cfrqcS2.b1.20220701.052741.nc',
#        'houcsapr2cfrqcS2.b1.20220701.053756.nc',
#        'houcsapr2cfrqcS2.b1.20220701.054749.nc',
#        'houcsapr2cfrqcS2.b1.20220701.055757.nc',
#        'houcsapr2cfrqcS2.b1.20220701.060748.nc',
#        'houcsapr2cfrqcS2.b1.20220701.061757.nc',
#        'houcsapr2cfrqcS2.b1.20220701.062748.nc',
#        'houcsapr2cfrqcS2.b1.20220701.063758.nc',
#        'houcsapr2cfrqcS2.b1.20220701.064749.nc',
#        'houcsapr2cfrqcS2.b1.20220701.065757.nc',
#        'houcsapr2cfrqcS2.b1.20220701.070747.nc',
#        'houcsapr2cfrqcS2.b1.20220701.071758.nc',
#        'houcsapr2cfrqcS2.b1.20220701.072730.nc',
#        'houcsapr2cfrqcS2.b1.20220701.073746.nc',
#        'houcsapr2cfrqcS2.b1.20220701.074759.nc',
#        'houcsapr2cfrqcS2.b1.20220701.075745.nc',
#        'houcsapr2cfrqcS2.b1.20220701.080759.nc',
#        'houcsapr2cfrqcS2.b1.20220701.081747.nc',
#        'houcsapr2cfrqcS2.b1.20220701.082800.nc',
#        'houcsapr2cfrqcS2.b1.20220701.083748.nc',
#        'houcsapr2cfrqcS2.b1.20220701.084758.nc',
#        'houcsapr2cfrqcS2.b1.20220701.085748.nc',
#        'houcsapr2cfrqcS2.b1.20220701.090758.nc',
#        'houcsapr2cfrqcS2.b1.20220701.091750.nc',
#        'houcsapr2cfrqcS2.b1.20220701.092756.nc',
#        'houcsapr2cfrqcS2.b1.20220701.093749.nc',
#        'houcsapr2cfrqcS2.b1.20220701.094758.nc',
#        'houcsapr2cfrqcS2.b1.20220701.095748.nc',
#        'houcsapr2cfrqcS2.b1.20220701.100800.nc',
#        'houcsapr2cfrqcS2.b1.20220701.101747.nc',
#        'houcsapr2cfrqcS2.b1.20220701.102800.nc',
#        'houcsapr2cfrqcS2.b1.20220701.103747.nc',
#        'houcsapr2cfrqcS2.b1.20220701.104759.nc',
#        'houcsapr2cfrqcS2.b1.20220701.105747.nc',
#        'houcsapr2cfrqcS2.b1.20220701.110800.nc',
#        'houcsapr2cfrqcS2.b1.20220701.111746.nc',
#        'houcsapr2cfrqcS2.b1.20220701.112801.nc',
#        'houcsapr2cfrqcS2.b1.20220701.113745.nc',
#        'houcsapr2cfrqcS2.b1.20220701.114802.nc',
#        'houcsapr2cfrqcS2.b1.20220701.115747.nc',
#        'houcsapr2cfrqcS2.b1.20220701.120758.nc',
#        'houcsapr2cfrqcS2.b1.20220701.121749.nc',
#        'houcsapr2cfrqcS2.b1.20220701.151747.nc',
#        'houcsapr2cfrqcS2.b1.20220701.152757.nc',
#        'houcsapr2cfrqcS2.b1.20220701.153750.nc',
#        'houcsapr2cfrqcS2.b1.20220701.154756.nc',
#        'houcsapr2cfrqcS2.b1.20220701.155749.nc',
#        'houcsapr2cfrqcS2.b1.20220701.160738.nc',
#        'houcsapr2cfrqcS2.b1.20220701.161755.nc',
#        'houcsapr2cfrqcS2.b1.20220701.162751.nc',
#        'houcsapr2cfrqcS2.b1.20220701.163754.nc',
#        'houcsapr2cfrqcS2.b1.20220701.164751.nc',
#        'houcsapr2cfrqcS2.b1.20220701.165756.nc',
#        'houcsapr2cfrqcS2.b1.20220701.170747.nc',
#        'houcsapr2cfrqcS2.b1.20220701.171758.nc',
#        'houcsapr2cfrqcS2.b1.20220701.172746.nc',
#        'houcsapr2cfrqcS2.b1.20220701.173758.nc',
#        'houcsapr2cfrqcS2.b1.20220701.174747.nc',
#        'houcsapr2cfrqcS2.b1.20220701.175758.nc',
#        'houcsapr2cfrqcS2.b1.20220701.180750.nc',
#        'houcsapr2cfrqcS2.b1.20220701.181756.nc',
#        'houcsapr2cfrqcS2.b1.20220701.182749.nc',
#        'houcsapr2cfrqcS2.b1.20220701.183757.nc',
#        'houcsapr2cfrqcS2.b1.20220701.184749.nc',
#        'houcsapr2cfrqcS2.b1.20220701.185757.nc',
#        'houcsapr2cfrqcS2.b1.20220701.190728.nc',
#        'houcsapr2cfrqcS2.b1.20220701.191745.nc',
#        'houcsapr2cfrqcS2.b1.20220701.192801.nc',
#        'houcsapr2cfrqcS2.b1.20220701.193746.nc',
#        'houcsapr2cfrqcS2.b1.20220701.194800.nc',
#        'houcsapr2cfrqcS2.b1.20220701.195748.nc',
#        'houcsapr2cfrqcS2.b1.20220701.200758.nc',
#        'houcsapr2cfrqcS2.b1.20220701.201749.nc',
#        'houcsapr2cfrqcS2.b1.20220701.202759.nc',
#        'houcsapr2cfrqcS2.b1.20220701.203747.nc',
#        'houcsapr2cfrqcS2.b1.20220701.204759.nc',
#        'houcsapr2cfrqcS2.b1.20220701.205748.nc',
#        'houcsapr2cfrqcS2.b1.20220701.211748.nc',
#        'houcsapr2cfrqcS2.b1.20220701.212758.nc',
#        'houcsapr2cfrqcS2.b1.20220701.213749.nc',
#        'houcsapr2cfrqcS2.b1.20220701.214758.nc',
#        'houcsapr2cfrqcS2.b1.20220701.215725.nc',
#        'houcsapr2cfrqcS2.b1.20220701.220748.nc',
#        'houcsapr2cfrqcS2.b1.20220701.221759.nc',
#        'houcsapr2cfrqcS2.b1.20220701.222748.nc',
#        'houcsapr2cfrqcS2.b1.20220701.224746.nc',
#        'houcsapr2cfrqcS2.b1.20220701.225801.nc',
#        'houcsapr2cfrqcS2.b1.20220701.230746.nc',
#        'houcsapr2cfrqcS2.b1.20220701.231801.nc',
#        'houcsapr2cfrqcS2.b1.20220701.232746.nc',
#        'houcsapr2cfrqcS2.b1.20220701.233802.nc',
#        'houcsapr2cfrqcS2.b1.20220701.234746.nc',
#        'houcsapr2cfrqcS2.b1.20220701.235800.nc',
#        'houcsapr2cfrqcS2.b1.20220702.000746.nc',
#        'houcsapr2cfrqcS2.b1.20220702.001801.nc',
#        'houcsapr2cfrqcS2.b1.20220702.002746.nc',
#        'houcsapr2cfrqcS2.b1.20220702.003802.nc',
#        'houcsapr2cfrqcS2.b1.20220702.004745.nc',
#        'houcsapr2cfrqcS2.b1.20220702.005802.nc',
#        'houcsapr2cfrqcS2.b1.20220702.010744.nc',
#        'houcsapr2cfrqcS2.b1.20220702.011800.nc',
#        'houcsapr2cfrqcS2.b1.20220702.012725.nc',
#        'houcsapr2cfrqcS2.b1.20220702.013744.nc',
#        'houcsapr2cfrqcS2.b1.20220702.014801.nc',
#        'houcsapr2cfrqcS2.b1.20220702.015746.nc',
#        'houcsapr2cfrqcS2.b1.20220702.020800.nc',
#        'houcsapr2cfrqcS2.b1.20220702.021746.nc',
#        'houcsapr2cfrqcS2.b1.20220702.022759.nc',
#        'houcsapr2cfrqcS2.b1.20220702.023743.nc',
#        'houcsapr2cfrqcS2.b1.20220702.024800.nc',
#        'houcsapr2cfrqcS2.b1.20220702.025746.nc',
#        'houcsapr2cfrqcS2.b1.20220702.030801.nc',
#        'houcsapr2cfrqcS2.b1.20220702.031745.nc',
#        'houcsapr2cfrqcS2.b1.20220702.032800.nc',
#        'houcsapr2cfrqcS2.b1.20220702.033744.nc',
#        'houcsapr2cfrqcS2.b1.20220702.034800.nc',
#        'houcsapr2cfrqcS2.b1.20220702.035746.nc',
#        'houcsapr2cfrqcS2.b1.20220702.040758.nc',
#        'houcsapr2cfrqcS2.b1.20220702.041750.nc',
#        'houcsapr2cfrqcS2.b1.20220702.042758.nc',
#        'houcsapr2cfrqcS2.b1.20220702.043749.nc',
#        'houcsapr2cfrqcS2.b1.20220702.044756.nc',
#        'houcsapr2cfrqcS2.b1.20220702.045748.nc',
#        'houcsapr2cfrqcS2.b1.20220702.050758.nc',
#        'houcsapr2cfrqcS2.b1.20220702.051746.nc',
#        'houcsapr2cfrqcS2.b1.20220702.052759.nc',
#        'houcsapr2cfrqcS2.b1.20220702.053747.nc',
#        'houcsapr2cfrqcS2.b1.20220702.054800.nc',
#        'houcsapr2cfrqcS2.b1.20220702.055746.nc',
#        'houcsapr2cfrqcS2.b1.20220702.060800.nc',
#        'houcsapr2cfrqcS2.b1.20220702.061746.nc',
#        'houcsapr2cfrqcS2.b1.20220702.062800.nc',
#        'houcsapr2cfrqcS2.b1.20220702.063744.nc',
#        'houcsapr2cfrqcS2.b1.20220702.064800.nc',
#        'houcsapr2cfrqcS2.b1.20220702.065747.nc',
#        'houcsapr2cfrqcS2.b1.20220702.070759.nc',
#        'houcsapr2cfrqcS2.b1.20220702.071746.nc',
#        'houcsapr2cfrqcS2.b1.20220702.072802.nc',
#        'houcsapr2cfrqcS2.b1.20220702.073746.nc',
#        'houcsapr2cfrqcS2.b1.20220702.074800.nc',
#        'houcsapr2cfrqcS2.b1.20220702.075745.nc',
#        'houcsapr2cfrqcS2.b1.20220702.080759.nc',
#        'houcsapr2cfrqcS2.b1.20220702.081729.nc',
#        'houcsapr2cfrqcS2.b1.20220702.082746.nc',
#        'houcsapr2cfrqcS2.b1.20220702.083800.nc',
#        'houcsapr2cfrqcS2.b1.20220702.084745.nc',
#        'houcsapr2cfrqcS2.b1.20220702.085801.nc',
#        'houcsapr2cfrqcS2.b1.20220702.090745.nc',
#        'houcsapr2cfrqcS2.b1.20220702.091800.nc',
#        'houcsapr2cfrqcS2.b1.20220702.092745.nc',
#        'houcsapr2cfrqcS2.b1.20220702.093802.nc',
#        'houcsapr2cfrqcS2.b1.20220702.094745.nc',
#        'houcsapr2cfrqcS2.b1.20220702.095801.nc'], dtype='<U38')

# %%
##########################################################
#TESTING

# %%
# # TRYIGN TO CALCULATE MYSELF (==> USE PYART by ARM INSTEAD)
# import os
# import numpy as np
# import xarray as xr
# import matplotlib.pyplot as plt

# class RadarScan:
#     def __init__(self, RadarType="PPI", index=0):
#         """
#         Initialize a RadarScan object.

#         Parameters
#         ----------
#         RadarType : str
#             Radar type (e.g., 'PPI', 'RHI', 'HSRHI', 'VPT').
#         index : int
#             Index of the file in the file list.
#         """
#         # Use your helper functions
#         self.Data_Directory, self.FileList = GetDataDirectory(RadarType=RadarType)
#         self.DataNC, self.DataFile = GetData(self.Data_Directory, self.FileList, index=index)
#         self.DataName = os.path.basename(self.DataFile)

#         # Extract metadata & variables
#         self._extract_metadata()
#         self._extract_variables()
#         self._get_PyArt_colormaps()
#         self._compute_cartesian()
#         self._compute_latlon()

#         # Close dataset (arrays remain in memory)
#         self.DataNC.close()

#     def _extract_metadata(self):
#         # Radar site location
#         self.radar_latitude = float(self.DataNC["latitude"].values)
#         self.radar_longitude = float(self.DataNC["longitude"].values)
#         self.radar_altitude = float(self.DataNC["altitude"].values)

#         # Dimensions
#         self.nt = self.DataNC.sizes["time"]   # rays
#         self.nr = self.DataNC.sizes["range"]  # gates

#         # Coordinates
#         self.times = self.DataNC["time"].values         # shape (nt,)
#         self.ranges = self.DataNC["range"].values       # shape (nr,)
#         self.azimuths = self.DataNC["azimuth"].values   # shape (nt,)
#         self.elevations = self.DataNC["elevation"].values  # shape (nt,)

#         # Convenience time info
#         self.TimeRange = (self.times[0], self.times[-1])

#     def _extract_variables(self):
#         # Reflectivity [ray, gate]
#         self.reflectivity = self.DataNC["reflectivity"].values  # shape (nt, nr)

#     def _get_PyArt_colormaps(self):
#         import pyart
#         self.cmap_reflectivity = pyart.config.get_field_colormap("reflectivity")

#     def _compute_cartesian(self):
#         """
#         Compute Cartesian coordinates (x,y) for all rays in a sweep.
#         """
#         # Rays = rows, ranges = columns
#         r, theta = np.meshgrid(self.ranges, np.deg2rad(self.azimuths))
#         self.x = r * np.sin(theta)   # east-west [m]
#         self.y = r * np.cos(theta)   # north-south [m]

#     def _compute_latlon(self):
#         """
#         Convert Cartesian (x,y) offsets to latitude/longitude.
#         """
#         R = 6.371e6  # Earth radius [m]
#         dLat = (self.y / R) * (180 / np.pi)
#         dLon = (self.x / (R * np.cos(np.deg2rad(self.radar_latitude)))) * (180 / np.pi)

#         self.Latitude = self.radar_latitude + dLat
#         self.Longitude = self.radar_longitude + dLon

#     def summary(self):
#         print(f"Radar file: {self.DataName}")
#         print(f"Time range: {self.TimeRange[0]} to {self.TimeRange[1]}")
#         print(f"Radar location: ({self.radar_latitude:.4f}, {self.radar_longitude:.4f}, {self.radar_altitude:.1f} m)")
#         print(f"Reflectivity shape: {self.reflectivity.shape} (rays, gates)")
#         print(f"Lat/Lon grid shape: {self.Latitude.shape}")

#     def PlotReflectivity(self, sweep_title=None, vmin=-10, vmax=60):
#         """
#         Plot a full PPI sweep (all azimuths in the file).
#         """
#         fig, ax = plt.subplots(figsize=(6, 6))

#         cs = ax.contourf(
#             self.Longitude, self.Latitude, self.reflectivity,
#             levels=np.linspace(vmin, vmax, 30),
#             cmap=self.cmap_reflectivity, vmin=vmin, vmax=vmax
#         )
#         plt.colorbar(cs, ax=ax, label="Reflectivity (dBZ)")

#         ax.set_xlabel("Longitude")
#         ax.set_ylabel("Latitude")
#         ax.set_aspect("equal")

#         # Mark radar location
#         ax.plot(self.radar_longitude, self.radar_latitude, "o",
#                 color="black", markersize=8)

#         # Title
#         if sweep_title is None:
#             sweep_title = f"PPI Reflectivity\nStart {self.times[0]} End {self.times[-1]}"
#         ax.set_title(sweep_title, fontsize=12)
#         plt.show()
