# %%
#SETTING UP DIRECOTRIES
mainDirectory = "/glade/u/home/aroseman/Projects/Regional-MPAS-Project/Code/CodeFiles/"
file1=mainDirectory+"../DATA/ERA5_Data/06-08_-_06-10_2022/u_component_of_wind_ERA5_06-08_-_06-10_2022.nc"
# file2=mainDirectory+"../DATA/ERA5_Data/06-30_-_07-02_2022/u_component_of_wind_ERA5_06-30_-_07-02_2022.nc"
# file3=mainDirectory+"../DATA/ERA5_Data/08-11_-_08-13_2022/u_component_of_wind_ERA5_08-11_-_08-13_2022.nc"

# %%
import xarray as xr
import numpy as np

# %%
File1=xr.open_dataset(file1)
#File1['valid_time']
File1

# File2=xr.open_dataset(file2)
#File2['valid_time']
# Out:
# <xarray.Dataset> Size: 4MB
# Dimensions:         (valid_time: 72, pressure_level: 32, latitude: 20,
#                      longitude: 23)
# Coordinates:
#     number          int64 8B ...
#   * valid_time      (valid_time) datetime64[ns] 576B 2022-06-08 ... 2022-06-1...
#   * pressure_level  (pressure_level) float64 256B 1e+03 975.0 ... 20.0 10.0
#   * latitude        (latitude) float64 160B 32.0 31.75 31.5 ... 27.75 27.5 27.25
#   * longitude       (longitude) float64 184B -98.0 -97.75 -97.5 ... -92.75 -92.5
#     expver          (valid_time) <U4 1kB ...
# Data variables:
#     u               (valid_time, pressure_level, latitude, longitude) float32 4MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
# ...

# %%
# one=File1.isel(valid_time=0,pressure_level=0)['u'].data
# two=File2.isel(valid_time=0,pressure_level=0)['u'].data
# np.all(one==two)
